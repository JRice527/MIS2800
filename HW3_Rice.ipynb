# %% [markdown]
# <a href="https://colab.research.google.com/github/JRice527/MIS2800/blob/main/HW3_Rice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# #I answered each question after each block of code

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %% [markdown]
# #

# %% [markdown]
# # Compared to the blocks from IC3 and saw the word "TABLE" was missing and added it

# %%
# %%sql
# INSERT INTO Marketing_Brands(brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1,'Doritos', 'Snacks', 7000000),
#   (2,'AWS','Technology',15000000),
#   (3,'Pepsi','Beverages',2000000),
#   (4,'He_Gets_US','Religous',1000000),
#   (5,'Dr_Pepper','Beverages',5000000),
#   (6,'IBM','Technology',100000),
#   (7,'Google','Technology',8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %% [markdown]
# # Noticed it was missing where these values were being inserted into, so added the table name

# %%
# %%sql
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_US', 'Religous', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %% [markdown]
# # Was missing the "*" after SELECT so added it

# %%
# %%sql
# SELECT brand_name, brand_type
# FROM Marketing_Brands
# WHERE brand_budget > 700000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_US', 'Religous'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %% [markdown]
# # Code needed to select only brand types and names so added those along with a filter for brands only above 700000

# %%
# %%sql
# SELECT * from Marketing_Brands
# WHERE brand_type = 'Religous'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_US', 'Religous', 1000000)]

# %% [markdown]
# #Added filter to only show religous brands

# %%
# %%sql
# SELECT brand_name from Marketing_Brands
# WHERE brand_budget < 1000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %% [markdown]
# #Selected only brand names and filtered by brands with less than 1000000 budget

# %%
# %%sql
# SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %% [markdown]
# #Added the %%sql

# %%
# %%sql
# SELECT brand_name
# FROM Marketing_Brands
# WHERE brand_type = 'Snacks' or brand_type = 'Beverages'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %% [markdown]
# #Added selecting only brand name and filtered for brand types snacks and beverages

# %%
# %%sql
# SELECT brand_name, brand_budget
# FROM Marketing_Brands
# ORDER BY brand_budget DESC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_US', 1000000),
#  ('IBM', 100000)]

# %% [markdown]
# #Selected only name and budget since those are what we want to display, and then sorted by budget in desc order

# %%
# %%sql
# SELECT * FROM Marketing_Brands
# ORDER BY brand_budget ASC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_US', 'Religous', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# #Added "%%sql" and then since it wants all columns did "Select *" and then sorted by brand budget is asc order
